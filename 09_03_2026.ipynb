# %% [markdown]
# <a href="https://colab.research.google.com/github/srihariniik/Python-Programing/blob/main/09_03_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Any banking Operation

acc_id=int(input("Enter acc_id: "))
acc_type=input("Enter acc_type: ")
acc_status=input("Enter acc_status: ")
acc_holder=input("Enter acc_holder: ")
trans_id=input("Enter transac_id: ")

tot_amt=5000
with_amt=float(input("Enter the withdrawal amt: "))

if with_amt>tot_amt:
  print("Invalid transaction")
else:
  rem_amt= print("Rem amt: ",tot_amt-with_amt)
# Out:
# Enter acc_id: 001
# Enter acc_type: saving acc
# Enter acc_status: active
# Enter acc_holder: harinii
# Enter transac_id: NXP001
# Enter the withdrawal amt: 6000
# Invalid transaction

# %%
# Calculating Simple Interest

principal_amt = float(input("Enter principal amount: ₹"))
annual_int_rate = float(input("Enter annual interest rate (%): "))
time_period = int(input("Enter time period (in years): "))

simple_interest = (principal_amt * annual_int_rate * time_period) / 100
print("Total: ₹", simple_interest+principal_amt)
# Out:
# Enter principal amount: ₹200000
# Enter annual interest rate (%): 20
# Enter time period (in years): 2
# Total: ₹ 280000.0

# %%
# Fraud Detection

trans_id=input("Enter transac_id: ")
tot_amt=15000
limit=1000
with_amt=float(input("Enter the withdrawal amt: "))

if with_amt>tot_amt or with_amt>limit or tot_amt<=0:
  fraud=True
else:
  fraud=False

if fraud==True:
  print("Fraud Detected")
else:
  print("Balance amt: ",tot_amt-with_amt)
# Out:
# Enter transac_id: NPX001
# Enter the withdrawal amt: 20000
# Fraud Detected

# %%
# Volume of Sphere with radius r

import math

r=float(input("Enter radius: "))
v = (4/3) * math.pi * (r**3)
print("Volume: ",v)
# Out:
# Enter radius: 4
# Volume:  268.082573106329

# %%
# Volume of Sphere with radius 5

import math

v = (4/3) * math.pi * (5**3)
print("Volume: ",v)
# Out:
# Volume:  523.5987755982989

# %%
# Area of circle

import math

r=float(input("Enter radius: "))
a=math.pi*(r**2)
print(f"The area of the circle with radius {r} is: {a}")
# Out:
# Enter radius: 4
# Area:  50.26548245743669

# %%
# c -> f

c=float(40)
f=float((c*9/5)+32)
print(f"c is {c}, so f is",f)
# Out:
# c is 40.0, so f is 104.0

# %%
# f -> c

f=float(50)
c=float(f-32)*5/9
print(f"f is {f}, so c is",c)
# Out:
# f is 50.0, so c is 10.0

# %%
# Account balance threshold

current_bal=2500
alert_limit=5000
if current_bal<alert_limit:
  print("Low balance Alert!")
else:
  print("Balance is healthy")
# Out:
# Low balance Alert!
